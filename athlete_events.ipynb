# %% [markdown]
# <a href="https://colab.research.google.com/github/fesimaxu/Pandas-Puzzles/blob/main/athlete_events.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis on the History of Olympic
#
# ## using athlete_events.csv to tell the History of olympic

# %% [markdown]
# # Import of Python Libraries

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
# ## Fill in the NaN values with 0

# %%
df = pd.read_csv("C:\\Users\\Igwe\\Downloads\\Olympic_Athletes\\athlete_events.csv", index_col='ID')
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     0.0     0.0         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     0.0     0.0  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal
# ID
# 1        Basketball Men's Basketball     0
# 2       Judo Men's Extra-Lightweight     0
# 3            Football Men's Football     0
# 4        Tug-Of-War Men's Tug-Of-War  Gold
# 5   Speed Skating Women's 500 metres     0

# %%
df.tail()
# Out:
#                       Name Sex   Age  Height  Weight      Team  NOC  \
# ID
# 135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# ID
# 135569  1976 Winter  1976  Winter       Innsbruck         Luge
# 135570  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 135570  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 135571  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 135571  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# ID
# 135569                Luge Mixed (Men)'s Doubles     0
# 135570  Ski Jumping Men's Large Hill, Individual     0
# 135570        Ski Jumping Men's Large Hill, Team     0
# 135571                      Bobsleigh Men's Four     0
# 135571                      Bobsleigh Men's Four     0

# %%
df.dtypes
# Out:
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %% [markdown]
# # Pandas Analysis on the Athlete Event Dataset

# %%
df['Team'].value_counts().idxmax()
# Out:
# 'United States'

# %%
df['Year'].max()
# Out:
# 2016

# %%
df['Year'].min()
# Out:
# 1896

# %%
Athlete_Data= df.agg(
     {
            "Age": ["min", "max", "median", "skew", "mean"],
            "Height": ["min", "max", "median", "skew", "mean"],
            "Weight": ["min", "max", "median", "skew", "mean"],
       }
   )

# %%
Athlete_Data
# Out:
#               Age      Height      Weight
# min      0.000000    0.000000    0.000000
# max     97.000000  226.000000  214.000000
# median  24.000000  171.000000   64.000000
# skew     0.047219   -1.280985   -0.711820
# mean    24.663827  136.424553   54.305674

# %%
df[["Age", "Height", "Weight"]].describe()
# Out:
#                  Age         Height         Weight
# count  271116.000000  271116.000000  271116.000000
# mean       24.663827     136.424553      54.305674
# std         7.840652      73.450560      32.381492
# min         0.000000       0.000000       0.000000
# 25%        21.000000     157.000000      47.000000
# 50%        24.000000     171.000000      64.000000
# 75%        28.000000     180.000000      75.000000
# max        97.000000     226.000000     214.000000

# %% [markdown]
# # Data Virtualization Analysis with Matplot and Seaborn
# ## The title of each data virtualization explains the plot

# %%
top_10 = df["Team"].value_counts()[0:10]

top_10.plot(kind = 'bar', figsize =(10,8))
plt.title('All Time Medals of top 10 Teams')
# Out:
# Text(0.5, 1.0, 'All Time Medals of top 10 Teams')

# %%
US_medal_table = df[df['Team'] == 'United States']['Medal'].value_counts()

US_medal_table.plot(kind = 'bar', figsize = (10,8))
plt.title('All Time Medals of United States Medal Table')
# Out:
# Text(0.5, 1.0, 'All Time Medals of United States Medal Table')

# %%
US_medal_table = df[df['Team'] == 'Nigeria']['Medal'].value_counts()

US_medal_table.plot(kind = 'bar', figsize = (10,8))
plt.title('All Time Medals of Nigeria Medal Table')
# Out:
# Text(0.5, 1.0, 'All Time Medals of Nigeria Medal Table')

# %%
US_medal_table = df[df['Team'] == 'United States']['Sport'].value_counts()

US_medal_table.plot(kind = 'bar', figsize = (10,8))
plt.title('All Time United States Olympic Sport Table')
# Out:
# Text(0.5, 1.0, 'All Time United States Olympic Sport Table')

# %%
US_medal_table = df[df['Team'] == 'Nigeria']['Sport'].value_counts()

US_medal_table.plot(kind = 'bar', figsize = (10,8))
plt.title('All Time Nigeria Olympic Sport Table')
# Out:
# Text(0.5, 1.0, 'All Time Nigeria Olympic Sport Table')

# %%
plt.figure(figsize=(20, 8))
sns.countplot(df['Year'])

plt.xlabel('Years')
plt.ylabel('No. of Name')

plt.title('Total Athletes contribution in olympics over time')
# Out:
# C:\Users\Igwe\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Total Athletes contribution in olympics over time')

# %%
plt.figure(figsize=(15, 5))
highest_sport = df['Sport'].value_counts().index
sns.countplot(data=df, x='Sport', order=highest_sport)
plt.xticks(rotation=75)
plt.title('Sports with most awarded Medals')
plt.xlabel('Sport')
plt.ylabel('No. of Medals')
# Out:
# Text(0, 0.5, 'No. of Medals')

# %%
plt.figure(figsize=(20, 5))
team_highest_sport = df[df['Team'] == 'United States']['Sport'].value_counts().index
sns.countplot(data=df, x='Sport', order=team_highest_sport)
plt.xticks(rotation=75)
plt.title('United States Sports with most awarded Medals')
plt.xlabel('Sport')
plt.ylabel('No. of Medals')
# Out:
# Text(0, 0.5, 'No. of Medals')

# %%
plt.figure(figsize=(20, 5))
team_highest_sport = df[df['Team'] == 'Nigeria']['Sport'].value_counts().index
sns.countplot(data=df, x='Sport', order=team_highest_sport)
plt.xticks(rotation=75)
plt.title('Nigeria Sports with most awarded Medals')
plt.xlabel('Sport')
plt.ylabel('No. of Medals')
# Out:
# Text(0, 0.5, 'No. of Medals')

# %%
athlete_order = df['Name'].value_counts().head(10).index
plt.figure(figsize=(9, 5))
sns.countplot(data=df, y='Name', order=athlete_order)
plt.title('Top 10 Athletes with the most awarded Medals')
plt.xlabel('No. of awrded medals')
plt.ylabel('Athlete Name');

# %%
sns.countplot(x="Medal", hue="Sex", data=df)
plt.title('Medals by Sex')
# Out:
# Text(0.5, 1.0, 'Medals by Sex')

# %%
Sex_group = df.groupby(['Year', 'Sex']).size().unstack()

Sex_group.apply(lambda x:x/x.sum(), axis=1).plot(kind='barh', stacked=True, legend=False)

plt.legend(['Men', 'Women'], bbox_to_anchor=(1.0, 0.7))

plt.xlabel('Men / Women ratio')
plt.title('The gender ratio in summer Olympics')
# Out:
# Text(0.5, 1.0, 'The gender ratio in summer Olympics')
